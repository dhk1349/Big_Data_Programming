# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
path1='../3/'
file_name1=path1+'sorted_range_price.csv'
df_air=pd.read_csv(file_name1)

path2='../2/'
file_name2=path2+'sorted_neighborhood_factors.csv'
df_air2=pd.read_csv(file_name2)

# %%
df_air
# Out:
#   Unnamed: 0  accommodates_avg  accommodates_med  bedrooms_avg  bedrooms_med  \
# 0      0-100          1.998331               2.0      1.033854           1.0
# 1    100-200          3.120521               3.0      1.336538           1.0
# 2    200-300          3.964286               4.0      1.622917           1.0
# 3    300-400          4.775862               4.0      2.040698           2.0
# 4    400-500          4.811765               4.0      2.023529           2.0
# 5   500-1000          5.172840               5.0      2.337500           2.0
# 6  1000-5000          4.000000               4.0      2.142857           2.0
#
#    reviews_avg  reviews_med  \
# 0    26.202600          5.0
# 1    22.281481          5.0
# 2    17.336761          4.0
# 3    12.726562          4.0
# 4    10.380000          1.0
# 5    10.000000          0.0
# 6     0.000000          0.0
#
#                                        neighbor_list  length
# ...

# %%
plt.plot(df_air['Unnamed: 0'], df_air['accommodates_avg'])
plt.savefig('1.png')

# %%
plt.plot(df_air['Unnamed: 0'], df_air['bedrooms_avg'])
plt.savefig('2.png')

# %%
df_air2
# Out:
#                  Unnamed: 0  max of price  min of price  max of reviews  \
# 0                   Allston         550.0          20.0             118
# 1                  Back Bay        1372.0          41.0             283
# 2               Bay Village        1200.0          81.0              47
# 3               Beacon Hill         849.0          42.0             214
# 4                  Brighton         999.0          10.0             152
# 5               Charlestown        1000.0          55.0             198
# 6                 Chinatown         600.0          92.0             172
# 7                Dorchester         395.0          30.0             262
# 8                  Downtown        1000.0          38.0             188
# 9               East Boston         300.0          35.0             281
# 10                   Fenway        4000.0          25.0             223
# 11                Hyde Park         250.0          40.0              53
# ...

# %%
x = df_air2['Unnamed: 0']
y1 = df_air2['avg of reviews']
y2 = df_air2['avg of satisfaction']
y3 = df_air2['avg of price']

plt.subplot(3,1,1)
plt.plot(x,y1)
plt.subplot(3,1,2)
plt.plot(x,y2)
plt.subplot(3,1,3)
plt.plot(x,y3)
plt.savefig('3.png')
plt.show()
